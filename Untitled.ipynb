# %%
# Project 1: Explore DC_Properties.csv dataset

# Explore the data

# %%
#import libraries
import pandas as pd
import numpy as np
#load data with headers
location = "datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#look at first 5 rows of data
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
#look at last 5 rows of data
df.tail()
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158952      158952       1          0  Forced Air  Y        NaN      3      1
# 158953      158953       1          0  Forced Air  Y        NaN      4      2
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 158952  1938.0   2006.0   ...     -77.01942            Old City 2
# 158953  1938.0   2006.0   ...     -77.01942            Old City 2
# 158954  1920.0   2007.0   ...     -77.01942            Old City 2
# 158955  1965.0      NaN   ...     -77.01823  Southwest Waterfront
# 158956  1965.0      NaN   ...     -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# ...

# %%
#show column names
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#show data type of each column
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
#count rows
len(df)
# Out:
# 158957

# %%
#number of non-NA values
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
#look at the data in the PRICE column
df['PRICE'].max()
# Out:
# 137427545.0

# %%
df['PRICE'].min()
# Out:
# 1.0

# %%
df['PRICE'].mean()
# Out:
# 931351.5949336156

# %%
df['PRICE'].median()
# Out:
# 399999.0

# %%
df['PRICE'].mode()
# Out:
# 0    350000.0
# dtype: float64

# %%
df['PRICE'].value_counts()
# Out:
# 350000.0     595
# 250000.0     536
# 300000.0     523
# 450000.0     519
# 375000.0     488
# 325000.0     482
# 550000.0     459
# 275000.0     455
# 500000.0     426
# 320000.0     425
# 200000.0     422
# 425000.0     419
# 600000.0     403
# 315000.0     402
# 330000.0     396
# 650000.0     387
# 525000.0     387
# 285000.0     377
# 225000.0     376
# 265000.0     374
# 310000.0     371
# 475000.0     364
# 360000.0     364
# 260000.0     360
# 280000.0     352
# 385000.0     352
# 335000.0     352
# 220000.0     349
# 240000.0     348
# 230000.0     347
#             ...
# 168700.0       1
# 674755.0       1
# 5397500.0      1
# 168670.0       1
# 674670.0       1
# 468400.0       1
# 337325.0       1
# 1096000.0      1
# 337562.0       1
# 1350250.0      1
# 337575.0       1
# 117164.0       1
# 84461.0        1
# 468890.0       1
# 84450.0        1
# 84449.0        1
# 503850.0       1
# 337750.0       1
# 675490.0       1
# 114620.0       1
# 466250.0       1
# ...

# %%
df['PRICE'].describe()
# Out:
# count    9.821600e+04
# mean     9.313516e+05
# std      7.061325e+06
# min      1.000000e+00
# 25%      2.400000e+05
# 50%      3.999990e+05
# 75%      6.520000e+05
# max      1.374275e+08
# Name: PRICE, dtype: float64

# %%
#Cleaning up the data
#check for duplicated rows
dupe=df.duplicated()
df.loc[dupe]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
#PRICE has 98216 non-NA values. Since there are 158957 rows, there are many rows without a price. 
#Create a new dataframe eliminating those null rows
df = df.dropna(axis=0, subset=['PRICE'])

# %%
len (df)
# Out:
# 98216

# %%
#OMG - it worked!!!!
df['PRICE'].describe()
# Out:
# count    9.821600e+04
# mean     9.313516e+05
# std      7.061325e+06
# min      1.000000e+00
# 25%      2.400000e+05
# 50%      3.999990e+05
# 75%      6.520000e+05
# max      1.374275e+08
# Name: PRICE, dtype: float64

# %%
#further reduce table to rows where price is between 25% and 75% percentil of values -- ie,, the middle 50% of prices
midprices = df.loc[(df['PRICE'] > 240000) & (df['PRICE'] < 652000)]
midprices
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 37              37       2          2      Warm Cool  Y        2.0      8
# 45              45       3          1     Forced Air  Y        2.0     10
# 48              48       2          1     Forced Air  N        2.0      8
# 54              54       1          1     Forced Air  Y        2.0      4
# 58              58       1          0  Hot Water Rad  N        2.0      4
# 61              61       3          1     Forced Air  Y        2.0      8
# 65              65       3          1  Hot Water Rad  Y        3.0      8
# 69              69       3          1  Hot Water Rad  N        3.0     10
# 77              77       2          1      Warm Cool  Y        2.0     11
# 92              92       2          0  Hot Water Rad  N        1.0      7
# 132            132       1          0      Warm Cool  Y        1.0      6
# ...

# %%
#Check to see the difference in the maximum number of bathrooms for the whole data set vs. for the dataset containing the middle
# 50% of prices
midprices['BATHRM'].max()
# Out:
# 9

# %%
df['BATHRM'].max()
# Out:
# 12

# %%
#Check to see the difference in the number of bedrooms for the whole data set vs. for the dataset containing the middle 50%
midprices['BEDRM'].max()
# Out:
# 13

# %%
df['BEDRM'].max()
# Out:
# 20

# %%
df['PRICE'].groupby(df['QUADRANT']).mean()
# Out:
# QUADRANT
# NE    3.928715e+05
# NW    1.317785e+06
# SE    3.682260e+05
# SW    3.470489e+05
# Name: PRICE, dtype: float64

# %%
#Interesting things to conclude about the data:
# Some fields have null values. For a column like 'PRICES', more than 1/3 of the rows have null values (about 60K out of 150K).
# I learned how to eliminate those rows. I also learned how to create a slice of the data containing only certain values. By
# slicing out the houses whose prices fall in the middle 50%, I could see that those middle 50% run from $250K to $650K. That
# makes the housing prices in DC seem not as outrageously high as I had assumed. The mean of the data is $399,999 but the median is
# $931,351. So it appears that there must be a lot of really expensive houses that inflate the mean. When you slice the data by 
# quadrant, you can see that those expensive houses that skew the mean are in the NW because the mean for the NW is about 4 times
# that of the other 3 quadrants.
